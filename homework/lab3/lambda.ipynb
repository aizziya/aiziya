# %%
#1
check = lambda x: 'positive' if x>0 else ('negative' if x<0 else 'zero')
print(check(1))
print(check(-1))
# Out:
# positive
# negative

# %%
#2
words = ["арбуз", "кот", "машина", "дом", "ананас"]

result = sorted(words, key=lambda w: (len(w), w[0]))

print(result)
# Out:
# ['дом', 'кот', 'арбуз', 'ананас', 'машина']

# %%
#3
numbers = [5, 12, 7, 20, 33, 8]

result = list(filter(lambda x: x % 2 == 0 and x > 10, numbers))

print(result)
# Out:
# [12, 20]

# %%
#4
numbers = [1, 2, 3, 4, 5, 6]

result = list(map(lambda x: x**2 if x % 2 == 0 else x*3, numbers))

print(result)
numbers = [1, 2, 3, 4, 5, 6]

result = list(map(lambda x: x**2 if x % 2 == 0 else x*3, numbers))

print(result)
# Out:
# [3, 4, 9, 16, 15, 36]
# [3, 4, 9, 16, 15, 36]

# %%
#5
compare = lambda a, b: "a больше" if a > b else ("b больше" if b > a else "равны")

print(compare(10,7))
print(compare(3,5))
print(compare(4,4))
# Out:
# a больше
# b больше
# равны

# %%
#6
numbers = [0, -3, 5, -7, 8]
result = [(lambda x: 'positive' if x>0 else ('negative' if x<0 else 'zero')) (x) for x in numbers]
print(result)
# Out:
# ['zero', 'negative', 'positive', 'negative', 'positive']
